# %% [markdown]
# # 07 - Visualization and Plots
#
# This notebook is the final reporting/plotting layer.
# Use it to aggregate metrics and produce publication-quality figures.

# %% [markdown]
# ## Suggested Workflow
# - Load saved metrics and trajectories from previous notebooks.
# - Create consistent plot styles (font sizes, line widths, labels).
# - Save figures as SVG/PDF for publication.

# %%
import matplotlib.pyplot as plt

plt.rcParams.update({
    "font.size": 12,
    "axes.titlesize": 14,
    "axes.labelsize": 12,
    "legend.fontsize": 10,
})

print("Ready to plot.")
# Out:
# Ready to plot.
